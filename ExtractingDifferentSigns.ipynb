# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshnsr/Sign-Assessment/blob/main/ExtractingDifferentSigns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !unzip allSigns.zip
# Out:
# Archive:  allSigns.zip
#    creating: allSigns/

# %%
allSignsDf = pd.read_csv("/content/finalalgoresult(May1).csv")
allSignsDf
# Out:
#       Sign_ID       ID     Easting     Northing  Altitude  Retro    Angle  \
# 0           0   673558  737713.170  3754983.019   276.132  0.804  0.07837
# 1           0   673559  737713.161  3754983.019   276.037  0.800  0.06810
# 2           0   673560  737713.168  3754983.030   275.942  0.804  0.05782
# 3           0   673561  737713.162  3754983.032   275.847  0.804  0.04755
# 4           0   673562  737713.154  3754983.033   275.752  0.800  0.03727
# ...       ...      ...         ...          ...       ...    ...      ...
# 6528       35  3079366  742555.982  3755480.206   290.454  0.816  0.02704
# 6529       35  3079367  742555.976  3755480.215   290.134  0.780  0.01674
# 6530       35  3079457  742555.979  3755480.279   290.773  0.812  0.03743
# 6531       35  3079458  742555.977  3755480.286   290.455  0.808  0.02714
# 6532       35  3079459  742555.983  3755480.290   290.137  0.737  0.01685
#
#       Distance          UTC       Long        Lat   Pic
# ...

# %%
allSignIds = allSignsDf.Sign_ID.unique()

# %%
from numpy import singlecomplex
pathToAllSigns = "/content/allSigns"
for signId in allSignIds:
  signDf = allSignsDf[allSignsDf['Sign_ID'] == signId]
  signDfPath = pathToAllSigns + "/sign" + str(signId) + ".csv"
  signDf.to_csv(signDfPath)

# %%
# Out:
# zip error: Nothing to do! (allSigns.zip)
